# %%
import glob
from nltk.tokenize import word_tokenize
from nltk.tokenize import sent_tokenize
import string
from collections import Counter
import re
from collections import OrderedDict
from tqdm import tqdm_notebook as tqdm1
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
import operator
import math
from textblob import TextBlob
from num2words import num2words
import pandas as pd
import numpy as np 
from sklearn import metrics
from sklearn.metrics import confusion_matrix

# %%
dp=pd.read_csv("/Users/ganesh/Desktop/IR_Project_Home/electronics_review.csv")

# %%
dp
# Out:
#      Unnamed: 0                                               idss  \
# 0             0  B00006HYUB:everyone_should_own_one:d._john_''l...
# 1             1                 B00006HYUB:breif_review:scott_park
# 2             2  B00006HYUB:works_fine.:dee_richards_''deeanaly...
# 3             3  B000067VBM:affordable_and_effective:jason_dick...
# 4             4  B00008SCFU:it_is_a_good_product_:kiran_k._sing...
# 5             5                      B0007P4G76:perfect:r._johnson
# 6             6  B0000DK3I4:kingston_1gb_sd_card_review:eugene_ong
# 7             7  B0000DK3I4:very_good_sd_card:gabriel_gore_''ge...
# 8             8           B0002MSTWC:flash_card:allen_l._mccartney
# 9             9       B0002MSTWC:works_great_for_me!:robert_farlee
# 10           10        B0006G0RSI:good_little_speakers!:folsom_mom
# 11           11  B0006ZSW1S:excellent_option_to_avoid_camera_ca...
# 12           12                         B0001DI6FW:does_the_job:ks
# 13           13       B0000CD08M:great_product:h._knox_''h._knox''
# 14           14  B0000CD08M:a_sandisk_fan:audra_m._fischenich_'...
# 15           15        B000BKE8QQ:almost_perfect:shawn_fitzgibbons
# 16           16  B0002MSTW2:fast_reader/writer_:shawn_m._mathes...
# 17           17  B00083XXZS:sandisk_2_gb_ultra_ii_memory_stick_...
# 18           18                   B00083XXZS:big_&_fast!:ikesingle
# 19           19  B00016L0VQ:not_the_right_item:charles_w._fain_...
# 20           20  B00065AO0K:nice_product,_does_the_job_nicely_....
# 21           21  B00065AO0K:fast,_really_faster_than_my_old_one...
# 22           22  B00065AO0K:the_perfect_add_on_for_your_camera:...
# 23           23                   B0000B3AKR:cheap_option:b._finzi
# 24           24  B0000B3AKR:it's_great,_but_has_one_small_probl...
# 25           25                  B00064V6R6:card_reader:c._legarra
# 26           26  B000BBCTHU:wish_i_had_gotten_a_bigger_one!:a._...
# 27           27          B000BBCTHU:excellent_beginners_tablet:4nr
# 28           28  B00070QI1S:kingston_1gb_sd_card_review:eugene_ong
# 29           29            B0002IWC9C:great:p._valbuena_''paulty''
# ..          ...                                                ...
# 970         970       B00006L4XU:awesome_accessory:''vc_george06''
# 971         971     B00079PNU6:the_sound_of_silence:cherif_elassar
# 972         972                  B0001F22PA:satisfied_customer:bud
# 973         973        B000BI2180:excellent_organizer!!:d._griblin
# 974         974      B00005V8Q8:free_upgrades_at_garmin_web_site:j
# 975         975  B0007WTHLO:the_isolation_is_great:douglas_r._d...
# 976         976      B000B9TV8W:love_it:shelley_cadamy_''shelley''
# 977         977  B0009VLF6S:how_to_deregister_phone:bernardo_za...
# 978         978        B000AY5ZIS:simple_review...:jeff_in_georgia
# 979         979  B0000AI0OE:small,_inexpensive,_reliable:owen_m...
# 980         980  B000056SPM:works_perfect_much_better_than_a_jo...
# 981         981  B0000V6YXQ:awesome_leather_case:n._tran_''slee...
# 982         982      B0000V6YXQ:excelente_producto:miguel_kingsley
# 983         983  B0007QCT0G:excellent_quality_and_design:pravin...
# 984         984  B0007QCT0G:versatile_backback,_good_protection...
# 985         985                B000F49ZHU:good_quality_phones:nora
# 986         986          B0000A1GOF:no_complaints:michelle_collazo
# 987         987        B0000A1GOF:all_around_xlnt_mouse!:peter_c_h
# 988         988            B00005TQ08:great_mouse:deborah_lampkins
# 989         989     B0002HS1A2:great_bang_for_your_buck!:m._presto
# 990         990  B000B63RIU:excellent_three_in_one_for_its_pric...
# 991         991          B0000C3GWV:good_product:robert_khachikyan
# 992         992  B0000BVUZ2:perfect_for_the_frequent_traveler:m...
# 993         993                   B0000BVUZ2:must_have!:pamelars24
# 994         994  B0007ZFLYI:does_what_its_supposed_too_but...:a...
# 995         995  B00006JHWA:canon's_best_value_for_photo_printi...
# 996         996  B00006JHWA:best_paper_for_canon_printers:b._ru...
# 997         997      B00032Q1IK:does_its_job_well:kris_''kristen''
# 998         998        B0007Q7MUI:holy_molly!!!:franklin_p._helton
# 999         999              B0007Q7MUI:holux_gm-270_ultra:j._ryan
#
#            asin                                       product_name  \
# 0    B00006HYUB  APC Back-UPS ES 500 Backup Battery and Surge P...
# 1    B00006HYUB  APC Back-UPS ES 500 Backup Battery and Surge P...
# 2    B00006HYUB  APC Back-UPS ES 500 Backup Battery and Surge P...
# 3    B000067VBM  50-pack Slim CD/DVD Jewel Cases ( 5mm ) Clear ...
# 4    B00008SCFU  Kingston 256 MB Secure Digital Card ( SD/256 )...
# 5    B0007P4G76  Xtreme TB264DKO 264-Disc CD/DVD Case : Electro...
# 6    B0000DK3I4  Kingston 512 MB Secure Digital Card ( SD/512 )...
# 7    B0000DK3I4  Kingston 512 MB Secure Digital Card ( SD/512 )...
# 8    B0002MSTWC  Lexar Media 512 MB 80x Pro Series Compact Flas...
# 9    B0002MSTWC  Lexar Media 512 MB 80x Pro Series Compact Flas...
# 10   B0006G0RSI  Altec Lansing inMotion iM3 - Portable speakers...
# 11   B0006ZSW1S  Kodak 8 - in - 1 Multi-card Reader , KRW8IN1SC...
# 12   B0001DI6FW  Targus PAUH212U 7 Port USB 2.0 Hub : Electronics
# 13   B0000CD08M  SanDisk SDCFH-512-901 512 MB Ultra II CompactF...
# 14   B0000CD08M  SanDisk SDCFH-512-901 512 MB Ultra II CompactF...
# 15   B000BKE8QQ  Altec Lansing inMotion iM716 Headphones : Elec...
# 16   B0002MSTW2  Lexar Media 1 GB 80x Pro Series Compact Flash ...
# 17   B00083XXZS  SanDisk 2 GB Ultra II Memory Stick PRO Duo : E...
# 18   B00083XXZS  SanDisk 2 GB Ultra II Memory Stick PRO Duo : E...
# 19   B00016L0VQ  Sandisk 512 MB Secure Digital Ultra II ( SDSDH...
# 20   B00065AO0K  SanDisk SDSDH-1024-901 1 GB Ultra II Secure Di...
# 21   B00065AO0K  SanDisk SDSDH-1024-901 1 GB Ultra II Secure Di...
# 22   B00065AO0K  SanDisk SDSDH-1024-901 1 GB Ultra II Secure Di...
# 23   B0000B3AKR  Viking USB00512L2 512 MB USB 2.0 Portable Mini...
# 24   B0000B3AKR  Viking USB00512L2 512 MB USB 2.0 Portable Mini...
# 25   B00064V6R6  SanDisk CF Type I/II ImageMate USB 2.0 Reader/...
# 26   B000BBCTHU  Wacom Graphire4 4x5 USB Tablet ( Silver ) : El...
# 27   B000BBCTHU  Wacom Graphire4 4x5 USB Tablet ( Silver ) : El...
# 28   B00070QI1S  Kingston 512MB Elite Pro Secure Digital Memory...
# 29   B0002IWC9C  Sony BCG-34HE4 Super-Quick Worldwide Battery C...
# ..          ...                                                ...
# 970  B00006L4XU  Targus PA215U Retractable Flat FireWire Cable ...
# 971  B00079PNU6  Sennheiser PXC 300 Noise Cancelling Headphones...
# 972  B0001F22PA  Belkin F8V3080 TuneCast II Mobile FM Transmitt...
# 973  B000BI2180                   Palm Z22 Handheld : Electronics
# 974  B00005V8Q8  Garmin MapSource CD ROM ( Americas BlueChart )...
# 975  B0007WTHLO  Etymotic Research ER6iC Isolator Earphones ( W...
# 976  B000B9TV8W  Apple MA183G/A Armband Blue for iPod Nano 1st ...
# 977  B0009VLF6S  Uniden TCX805 Accessory Handset For One- or Tw...
# 978  B000AY5ZIS  Logitech Cordless Desktop MX 5000 Laser ( 9675...
# 979  B0000AI0OE  Tripp lite 150W POWER INVERTER 1 OUTLET ( PV15...
# 980  B000056SPM  CH Products Flight Sim Yoke USB ( 200-615 ) : ...
# 981  B0000V6YXQ  HP Leather Belt Case for iPAQ H1900 & H2200 : ...
# 982  B0000V6YXQ  HP Leather Belt Case for iPAQ H1900 & H2200 : ...
# 983  B0007QCT0G  MAXXUM from SwissGear by Wenger Computer Backp...
# 984  B0007QCT0G  MAXXUM from SwissGear by Wenger Computer Backp...
# 985  B000F49ZHU  Panasonic KX-TG5623B Black 5.8 GHz FHSS GigaRa...
# 986  B0000A1GOF       Logitech MX 310 Optical Mouse : Electronics
# 987  B0000A1GOF       Logitech MX 310 Optical Mouse : Electronics
# 988  B00005TQ08  Microsoft Intellimouse Optical Mouse : Electro...
# 989  B0002HS1A2  Garmin GPS 18 Deluxe GPS Sensor with nRoute an...
# 990  B000B63RIU  HP Officejet 5610 All-in-One Printer , Copier ...
# 991  B0000C3GWV  JBL Duet PC Speakers ( 2-Speaker , Silver ) : ...
# 992  B0000BVUZ2  Targus PA206U Mini Retractable RJ-11 Cord ( Pl...
# 993  B0000BVUZ2  Targus PA206U Mini Retractable RJ-11 Cord ( Pl...
# 994  B0007ZFLYI  Logitech 961400-0403 Quickcam for Notebooks De...
# 995  B00006JHWA  Canon Photo Paper Plus , Glossy ( 7980A006 , 8...
# 996  B00006JHWA  Canon Photo Paper Plus , Glossy ( 7980A006 , 8...
# 997  B00032Q1IK  Lexar Media Single-Slot USB 2.0 Multi-Card Rea...
# 998  B0007Q7MUI  Holux GM-270 - GPS receiver module : Electronics
# 999  B0007Q7MUI  Holux GM-270 - GPS receiver module : Electronics
#
#     product_type  rating                                              title  \
# 0    electronics     5.0                           Everyone should own one
# 1    electronics     5.0                                      Breif Review
# 2    electronics     4.0                                      Works fine .
# 3    electronics     5.0                          Affordable and effective
# 4    electronics     5.0                              It is a good product
# 5    electronics     5.0                                           perfect
# 6    electronics     5.0                       Kingston 1GB SD Card Review
# 7    electronics     5.0                                 Very good SD Card
# 8    electronics     5.0                                        Flash Card
# 9    electronics     5.0                              Works great for me !
# 10   electronics     4.0                            Good little speakers !
# 11   electronics     5.0           Excellent option to avoid camera cables
# 12   electronics     5.0                                      Does the job
# 13   electronics     5.0                                     Great Product
# 14   electronics     5.0                                     A SanDisk Fan
# 15   electronics     4.0                                    Almost perfect
# 16   electronics     5.0                                Fast Reader/Writer
# 17   electronics     5.0        SanDisk 2 GB Ultra II Memory Stick Pro Duo
# 18   electronics     5.0                                      Big & Fast !
# 19   electronics     5.0                                Not the Right Item
# 20   electronics     5.0          Nice product , does the job nicely . . .
# 21   electronics     5.0             fast , really faster than my old ones
# 22   electronics     5.0                The Perfect Add On For Your Camera
# 23   electronics     5.0                                      Cheap option
# 24   electronics     4.0         it 's great , but has one small problem .
# 25   electronics     4.0                                       Card Reader
# 26   electronics     4.0                  wish I had gotten a bigger one !
# 27   electronics     5.0                        Excellent beginners tablet
# 28   electronics     5.0                       Kingston 1GB SD Card Review
# 29   electronics     5.0                                             great
# ..           ...     ...                                                ...
# 970  electronics     5.0                                 Awesome Accessory
# 971  electronics     5.0                              The Sound of Silence
# 972  electronics     4.0                                Satisfied customer
# 973  electronics     5.0                           Excellent organizer ! !
# 974  electronics     5.0                  free upgrades at Garmin web site
# 975  electronics     4.0                            The isolation is great
# 976  electronics     4.0                                           Love it
# 977  electronics     5.0                           How to deregister phone
# 978  electronics     5.0                                 Simple Review ...
# 979  electronics     5.0                    Small , inexpensive , reliable
# 980  electronics     5.0         Works perfect much better than a joystick
# 981  electronics     5.0                              awesome leather case
# 982  electronics     5.0                                Excelente producto
# 983  electronics     5.0                      Excellent quality and design
# 984  electronics     4.0  Versatile Backback , good protection , excelle...
# 985  electronics     4.0                               Good quality phones
# 986  electronics     5.0                                     No complaints
# 987  electronics     5.0                           ALL AROUND XLNT MOUSE !
# 988  electronics     5.0                                       Great mouse
# 989  electronics     5.0                        Great bang for your buck !
# 990  electronics     5.0        Excellent three in one for its price range
# 991  electronics     5.0                                      good product
# 992  electronics     5.0                 Perfect for the frequent traveler
# 993  electronics     5.0                                       Must Have !
# 994  electronics     5.0                Does what its supposed too but ...
# 995  electronics     5.0  CANON 'S BEST VALUE FOR PHOTO PRINTING ... TRU...
# 996  electronics     5.0                     Best paper for Canon printers
# 997  electronics     4.0                                 Does its job well
# 998  electronics     5.0                                  Holy Molly ! ! !
# 999  electronics     4.0                                Holux Gm-270 Ultra
#
#                                            review_text
# 0    I purchased this unit due to frequent blackout...
# 1    I ordered 3 APC Back-UPS ES 500s on the recomm...
# 2    Wish the unit had a separate online/offline li...
# 3    Cheaper than thick CD cases and less prone to ...
# 4    Hi I brought 256 MB Kingston SD card from Amaz...
# 5    This product was perfect . it 's a sturdy case...
# 6    Great value for your money . Kingston has alwa...
# 7    I like it very much , I use it in an outdoor t...
# 8    I had no problems with this card and the deliv...
# 9    After going through the reviews , I bought thi...
# 10   I am very happy with this product . It folds s...
# 11   I bought this reader because I wanted to avoid...
# 12   It 's a simple device , so there 's not to say...
# 13   I was thinking about buying a 1G card , but af...
# 14   I have always been very pleased with the SanDi...
# 15   These earphones are great quality . The sound ...
# 16   This CF card is so fast that I can run my shut...
# 17             fast and reliable..well worth the mone
# 18   Perhaps the ultimate addition to a good camera...
# 19   The Sandisk 512 MB Secure Digitial Ultra II ( ...
# 20   definitely recommend this memory card , downlo...
# 21   I am happy to have several Sandisk products , ...
# 22   The SanDisk SDSDH-1024-901 is absoultely worth...
# 23   The cheapest option I found at the time but an...
# 24   It works great ! I really like it . There is o...
# 25   Works well with or without software installed ...
# 26   This technically works well . I am finding lea...
# 27   I was considering purchasing a tablet and Waco...
# 28   Great value for your money . Kingston has alwa...
# 29   Great batteries for cameras . They charge quic...
# ..                                                 ...
# 970  This is the perfect product for someone who tr...
# 971  Works exactly as advertised - I travel a lot a...
# 972  Unit 's range shorter than expected , but I fe...
# 973  I was looking for a very basic palm that would...
# 974  If you ORIGINALLY & NEWLY unlocked a NEW locke...
# 975  If you 're looking for isolation from ambient ...
# 976  I found this on clearance at another retailer ...
# 977  The phone works great ! . I have three of thes...
# 978  I just use the keyboard like a business user ....
# 979  I used the Tripp lite to charge my PowerBook a...
# 980  Esactly what I was wanting . When you turn the...
# 981  nicely designed leather case w/ belt clip . i ...
# 982  Este estuche lo compr para mi iPaq hx2415 y e...
# 983  This backpack is ideal for carrying my huge sc...
# 984  Great all around backpack for lugging laptop a...
# 985  Great sound quality ; great signal quality . I...
# 986  This is definitely a comfortable mouse if you ...
# 987  PROS : xlnt quality long cord usb or ps2 conne...
# 988  I love it . You can switch back and forth from...
# 989  This is an excellent product . If you drive a ...
# 990  Obviously , there are far better printers on t...
# 991  Since I 've seen musicians use JBL speakers fo...
# 992  Note : This is a review of the Targus PA225U R...
# 993  This is wonderful for laptop users that travel...
# 994  I just got my quickcam and it was very easy to...
# 995  I have the Canon MP500 printer and Canon Rebel...
# 996  I tested my new Canon i960 with a variety of p...
# 997  I 've had this for at least 8 months now . We ...
# 998  This reciever is great ! It even gets receptio...
# 999  The GPS works in both my Dell Axim X5 and in m...
#
# [1000 rows x 8 columns]

# %%
dic_products_review_text={}
dic_products_review_title={}
dic_products_aspect={}
dic_products_aspect_title={}
for i in range(len(dp)):
    templist=[]
    prod_name=dp["product_name"][i]
    if prod_name in dic_products_review_text:
        dic_products_review_text[prod_name].append(dp["review_text"][i])
        dic_products_review_title[prod_name].append(dp["title"][i])
        
    else:
        dic_products_review_text[prod_name]=[]
        dic_products_review_title[prod_name]=[]
        dic_products_aspect[prod_name]={}
        dic_products_aspect_title[prod_name]={}
        dic_products_review_text[prod_name].append(dp["review_text"][i])
        dic_products_review_title[prod_name].append(dp["title"][i])

# %%
#average product rating
product_rating={}
for i in range(len(dp)):
    prod_name=dp["product_name"][i]
    if(prod_name in product_rating):
        product_rating[prod_name]+=dp["rating"][i]
    else:
        product_rating[prod_name]=dp["rating"][i]
for prod in product_rating :
     product_rating[prod]= product_rating[prod]/len(dic_products_review_text[prod])

# %%
import spacy
nlp = spacy.load("en_core_web_sm")

# %%
def adjnoun_pairs(x):
    doc = nlp(u''+x)
    noun_adj_pairs = []
    for i,token in enumerate(doc):
        if token.pos_ not in ('NOUN','PROPN'):
            continue
        for j in range(i+1,len(doc)):
            if doc[j].pos_ == 'ADJ':
                noun_adj_pairs.append([token,doc[j]])
                break
    return noun_adj_pairs

# %%
file1=open("/Users/ganesh/Desktop/Negative-word.txt",'r',encoding='utf-8',errors='ignore')
text1=file1.read()
negative_word_list=text1.split(',')

# %%
def is_negative(xx,product):
    pr_review=dic_products_review_text[product]
    rv_tok=sent_tokenize(pr_review[0])
    for sent in rv_tok:
        sent_word=word_tokenize(sent)
        i=0
        while(sent_word[i]!=xx and i<len(sent_word)-1):
            if(sent_word[i] in list(negative_word_list)):
                return -1
            i+=1
    return 1

# %%
def findpol(xx,product):
    #print(xx)
    x=TextBlob(xx)
    if(is_negative(xx,product)== -1):
        print("here")
        return ((x.sentiment.polarity)*-1)
        
    
    return (x.sentiment.polarity)

# %%
# for review text => calculate aspect count,polarity
dic_products_aspect_count={}
for products in dic_products_review_text:
    dic_products_aspect_count[products]={}
    aspect_count={}
    for i in range(len(dic_products_review_text[products])):
        templist=[]
        templist=adjnoun_pairs(dic_products_review_text[products][i])
        for aspects in templist:
            if aspects[0] not in dic_products_aspect[products].keys():
                aspect_count[str(aspects[0])]=1
                dic_products_aspect[products][str(aspects[0])]=findpol(str(aspects[1]),products)
            #print(aspects[0])
            else:
                aspect_count[str(aspects[0])]+=1
                dic_products_aspect[products][str(aspects[0])]+=findpol(str(aspects[1]),products)
    dic_products_aspect_count[products]=aspect_count
    for k in aspect_count.keys():
        dic_products_aspect[products][k]=dic_products_aspect[products][k]/aspect_count[k]

# %%
#for title 
dic_products_aspect_count_title={}
for products in dic_products_review_title:
    dic_products_aspect_count_title[products]={}
    aspect_count={}
    for i in range(len(dic_products_review_title[products])):
        templist=[]
        templist=adjnoun_pairs(dic_products_review_title[products][i])
        for aspects in templist:
            if aspects[0] not in dic_products_aspect_title[products].keys():
                aspect_count[str(aspects[0])]=1
                dic_products_aspect_title[products][str(aspects[0])]=findpol(str(aspects[1]),products)
            #print(aspects[0])
            else:
                aspect_count[str(aspects[0])]+=1
                dic_products_aspect_title[products][str(aspects[0])]+=findpol(str(aspects[1]),products)
    dic_products_aspect_count_title[products]=aspect_count
    
    for k in aspect_count.keys():
        dic_products_aspect_count_title[products][k]=dic_products_aspect_count_title[products][k]/aspect_count[k]

# %%
final_precision=[]
final_recall=[]
final_f1score=[]
final_ndcg15=[]
final_pr_p=[]
final_pr_r=[]
final_aspect=['quality','sound','memory','display','screen']
final_retrived=[]

# %%
#calculating final score with respect to aspect using body of review
aspect_input1=input("Enter aspect:")
aspect_input1=word_tokenize(aspect_input1)
print(aspect_input1)
top_product={}
for aspect_input in aspect_input1:
    for products in dic_products_review_text:
        score1=0
        if(aspect_input in dic_products_aspect[products].keys()):
            score1=dic_products_aspect[products][aspect_input]*dic_products_aspect_count[products][aspect_input]
            #print(products,'==',dic_products_aspect[products][aspect_input])
        score2=0    
        if(aspect_input in dic_products_aspect_title[products].keys()):
            score2=dic_products_aspect_title[products][aspect_input]*dic_products_aspect_count_title[products][aspect_input]

        if(products in top_product ):
            top_product[products]+=(score1)+product_rating[products]
        else:
            top_product[products]=(score1)+product_rating[products]
            
retrived_product1=dict( sorted(top_product.items(), key=operator.itemgetter(1),reverse=True))
retrived_product_list=list(retrived_product1.keys())
retrived_products=[]
for i in range(30):
    retrived_products.append(retrived_product_list[i])
    

ground_truth=ground_truth1[aspect_input]
intesection=set(ground_truth).intersection(set(retrived_products))
final_retrived.append(retrived_products)
ppp=len(intesection)/len(retrived_products)
rrr=len(intesection)/len(ground_truth)
fscore=(2*ppp*rrr)/(rrr+ppp)
print("ppp=",ppp,"|| rrr=",rrr,"||f1=",fscore)
rel=[]
for z in retrived_products:
    if(z in ground_truth):
        rel.append(1)
    else:
        rel.append(0)
ndcgat15=ndcg_at_k(np.array(rel),15)
print("ndcg=",ndcgat15)
#
total_relevant=0
for i in rel:
    if(i>0):
        total_relevant+=1
precision=[]
recall=[]
relevant=0
retrived=0
for i in range(len(rel)):
    if(rel[i]>0):
        relevant+=1
        retrived+=1
    else:
        retrived+=1
    
    precision.append(relevant/retrived)
    recall.append(relevant/total_relevant)

#



final_precision.append(ppp)
final_recall.append(rrr)
final_f1score.append(fscore)
final_ndcg15.append(ndcgat15)
final_pr_p.append(precision)
final_pr_r.append(recall)
# Out:
# Enter aspect:screen
# ['screen']
# ppp= 0.8666666666666667 || rrr= 0.7878787878787878 ||f1= 0.8253968253968254
# ndcg= 0.8916375323604091

# %%
def dcg_at_k(score, k = None):
    
    if k is not None:
        score = score[:k]

    gain = 2 ** score - 1
    discounts = np.log2(np.arange(2, score.size + 2))
    dcg = np.sum(gain / discounts)
    return dcg

# %%
def ndcg_at_k(score, k = None):
    
    actual_dcg = dcg_at_k(score, k)
    sorted_score = np.sort(score)[::-1]
    best_dcg = dcg_at_k(sorted_score, k)
    ndcg = actual_dcg / best_dcg
    return ndcg

# %%
ground_truth1={}

# %%
ground_truth1['quality']=['Kensington Slim Type Keyboard - PC ( 64365 ) : Electronics ',
                          'Olympus WS-320M 1 GB Digital Voice Recorder and Music Player : Electronics ',
 'Panasonic KX-TG5673B 5.8 GHz FHSS GigaRange Digital Cordless Telephone with Dual Handsets : Electronics ',
 
                          'Belkin 7-Outlet Surgemaster Home Series - F9H710-06 : Electronics ',
 'Belkin A3L791-S 25-Foot RJ45 CAT 5e Snagless Molded Patch Cable ( Blue ) : Electronics ',
 'Monster Cable QL GAS-H QuickLock Gold Angled Spade Connectors ( 2 Pair ) : Electronics ',
 'Panasonic KX-TG5771S 5.8 GHz FHSS GigaRange Expandable Digital Cordless Answering System : Electronics ',
 
 'Vtech I5871 - Expandable System w/ digital Answering Device , Color Handset Display & Dual Caller ID : Electronics ',
 'Creative Zen Nano Plus 1 GB MP3 Player ( Blue ) : Electronics ',
 'Panasonic KX-TG5761S 5.8 GHz FHSS GigaRange Expandable Digital Cordless Telephone : Electronics ',
                          'Bose SoundDock digital music system for iPod ( Black ) : Electronics ',
 'Creative Zen Micro Photo 4 GB MP3 Player Black : Electronics ',
 "Syntax Olevia LT30HV 30 '' HD-Ready Flat-Panel LCD TV : Electronics ",
 'Epson T009201 Stylus Photo Color Cartridge : Electronics ',
 
 'HP DeskJet 3845 Color Inkjet Printer : Electronics ',
 'Logitech Quickcam for Notebooks Pro : Electronics ',
 'Samsung DVD-R145 DVD Recorder : Electronics ',
                          'MAXXUM from SwissGear by Wenger Computer Backpack Red : Electronics ',
 'Ultimate Ears Super.fi 5 EB Earphones ( Black ) : Electronics ',
 'Monster Reference PowerCenter HTS 3500 MKII : Electronics ',
 'Linksys PAP2 Phone Adapter for Vonage Internet Phone Service : Electronics ',
 
 'Monster Cable MP HTS 1000 PowerCenter with Clean Power Stage 2 ( v.2.0 ) : Electronics ',
 'Apple 4 GB iPod Mini Pink M9435LL/A : Electronics ',
 'MACALLY IceTune Stereo Speaker and Charger : Electronics ',
 'Microsoft Digital Media Pro Keyboard : Electronics ',
 'Creative Labs USB SoundBlaster Live ! 24-Bit External Sound Card : Electronics ',
 'JBL Creature II 3-Piece Powered Speaker System : Electronics ',
 'Canon BCI-6Y Yellow Ink Tank : Electronics ',
 'SanDisk SDMX4-2048 Sansa e250 2 GB MP3 Player with SD Expansion Slot : Electronics ',
 'NeatReceipts Scanalizer Professional 2.5 Mobile Scanner & Software Combination for Business Cards , Expense Management and Reporting , Document Organization , Scanning & Copying : Electronics ',
 
 'HP OfficeJet 7410 All-in-One : Electronics ',
 'Sennheiser EH-150 Evolution Hi-Fi Stereo Headphones : Electronics '
                         'Logitech Wireless Headphones for MP3 : Electronics ']

# %%
ground_truth1['memory']=['Sony 1 GB Memory Stick Pro ( MSX1GS/GST ) : Electronics ',
 'SanDisk MOBILEMATE MS - 4 IN 1 ( SDDR-107-A10M , Retail Package ) : Electronics ',
 'SanDisk SDSDH-1024-901 1 GB Ultra II Secure Digital Memory Card ( Retail Package ) : Electronics ',
 'Sony ICD-MX20 Memory Stick Pro Duo Digital Voice Recorder : Electronics ',
 'Sony 1 GB Memory Stick PRO Duo Media ( MSXM1GST ) : Electronics ',
 'HP DVD Movie Writer dc4000 : Electronics ',
 'SanDisk SDMSG-1024 Pro Duo 1 GB Gaming Memory Stick : Electronics ',
 'SanDisk 1GB miniSD Card ( SDSDM-1024-A10M , Retail Package ) : Electronics ',
 'Kingston 1GB SecureDigital Flash Card ( SD/1GB ) : Electronics ',
 '50-pack Slim CD/DVD Jewel Cases ( 5mm ) Clear : Electronics ',
 'Kingston 256 MB Secure Digital Card ( SD/256 ) : Electronics ',
 'Xtreme TB264DKO 264-Disc CD/DVD Case : Electronics ',
 'Kingston 512 MB Secure Digital Card ( SD/512 ) : Electronics ',
 'Lexar Media 512 MB 80x Pro Series Compact Flash Card ( CF512-80-380 ) : Electronics ',
 'Kodak 8 - in - 1 Multi-card Reader , KRW8IN1SCS : Electronics ',
 'Targus PAUH212U 7 Port USB 2.0 Hub : Electronics ',
 'SanDisk SDCFH-512-901 512 MB Ultra II CompactFlash Card ( Retail Package ) : Electronics ',
 'Canon S830D Photo Printer : Electronics ',
 'SanDisk 2 GB Ultra II Memory Stick PRO Duo : Electronics ',
 'Sandisk 512 MB Secure Digital Ultra II ( SDSDH-512-901 , Retail Package ) : Electronics ',
 'Kingston 512MB Elite Pro Secure Digital Memory Card ( SD/512-S ) : Electronics ',
 'Sony BCG-34HE4 Super-Quick Worldwide Battery Charger with 4 AA NiMH Batteries : Electronics ',
 'Logitech NuLOOQ Navigator ( 965162-0403 ) : Electronics ',
 'SanDisk SDDR-88-A15 8-in-1 USB 2.0 Hi-speed Reader ( Retail Package ) : Electronics ',
 'Velocity DVD-R 4X 4.7GB , 10-Spindle : Electronics ',
 'SanDisk SDSDB-512-A10 512 MB Secure Digital Card ( Retail Package ) : Electronics ',
 'Hewlett Packard CD-Writer C4503A 9510i 12x8x32 Internal EIDE Kit : Electronics ',
 'Targus PAUH216U 4 Port Slim USB 2.0 Hub : Electronics ',
 'Sony BCG-34HRMF4 Super Quick Charger with LCD Indicator and 4 AA Batteries : Electronics ',
 'Wacom Intuos3 6X11 Pen Tablet : Electronics ',
 'SanDisk 2 GB SD Memory Card ( SDSDB-2048-A10 , Retail Package ) : Electronics ',
 'Memorex DVD+R 16x 4.7GB 50 Pack Spindle : Electronics ',
 'Panasonic DMR-ES10S DIGA Series DVD Recorder ( Silver ) : Electronics ']

# %%
ground_truth1['display']=['Apple 4 GB iPod Nano Green ( 2nd Generation ) : Electronics ',
    'Garmin GPSMap 76CSx Handheld Marine GPS Navigator : Electronics ',
 'Boston Acoustics Receptor Clock Radio ( Charcoal ) : Electronics ',
                          'Panasonic DMR-ES10S DIGA Series DVD Recorder ( Silver ) : Electronics ',
 'Panasonic SA-XR70S 6.1 Channel Surround Sound Home Theater Audio / Video Receiver - Silver : Electronics ',
 "Sony KDFE42A10 42 '' LCD Rear Projection Television : Electronics ",
                          'ADS Tech Video Xpress USBAV-191-EF : Electronics ',
 "ViewSonic Optiquest Q9b 19 '' LCD Monitor : Electronics ",
 'Sennheiser HD 457 Traditional Open Hi-Fi Stereo Headphones ( Silver ) : Electronics ',
         'Sony HT-DDW700 Complete 5.1-Channel DVD Home Theater System : Electronics ',
 "Samsung 215TW 21 '' LCD Monitor : Electronics ",
 '50-pack Slim CD/DVD Jewel Cases ( 5mm ) Clear : Electronics ',
 'Kingston 256 MB Secure Digital Card ( SD/256 ) : Electronics ',
 'Xtreme TB264DKO 264-Disc CD/DVD Case : Electronics ',
 'Kingston 512 MB Secure Digital Card ( SD/512 ) : Electronics ',
 'Lexar Media 512 MB 80x Pro Series Compact Flash Card ( CF512-80-380 ) : Electronics ',
 'Kodak 8 - in - 1 Multi-card Reader , KRW8IN1SCS : Electronics ',
 'SanDisk SDCFH-512-901 512 MB Ultra II CompactFlash Card ( Retail Package ) : Electronics ',
 'Lexar Media 1 GB 80x Pro Series Compact Flash Card ( CF1GB-80-380 ) : Electronics ',
 'SanDisk 2 GB Ultra II Memory Stick PRO Duo : Electronics ',
 'Sandisk 512 MB Secure Digital Ultra II ( SDSDH-512-901 , Retail Package ) : Electronics ',
 'SanDisk SDSDH-1024-901 1 GB Ultra II Secure Digital Memory Card ( Retail Package ) : Electronics ',
 'Kingston 512MB Elite Pro Secure Digital Memory Card ( SD/512-S ) : Electronics ',
 'Sony BCG-34HE4 Super-Quick Worldwide Battery Charger with 4 AA NiMH Batteries : Electronics ',
 'Logitech NuLOOQ Navigator ( 965162-0403 ) : Electronics ',
 'SanDisk SDDR-88-A15 8-in-1 USB 2.0 Hi-speed Reader ( Retail Package ) : Electronics ',
 'Velocity DVD-R 4X 4.7GB , 10-Spindle : Electronics ',
 'SanDisk SDSDB-512-A10 512 MB Secure Digital Card ( Retail Package ) : Electronics ',
 'Hewlett Packard CD-Writer C4503A 9510i 12x8x32 Internal EIDE Kit : Electronics ',
 'Targus PAUH216U 4 Port Slim USB 2.0 Hub : Electronics ',
 'Sony BCG-34HRMF4 Super Quick Charger with LCD Indicator and 4 AA Batteries : Electronics ',
 'Wacom Intuos3 6X11 Pen Tablet : Electronics ',
 'SanDisk 2 GB SD Memory Card ( SDSDB-2048-A10 , Retail Package ) : Electronics ']

# %%
ground_truth1['screen']=["Apple Cinema 30 '' HD Flat-Panel Display : Electronics ",
'Vtech I5871 - Expandable System w/ digital Answering Device , Color Handset Display & Dual Caller ID : Electronics ',
 'Creative Zen Micro Photo 4 GB MP3 Player Black : Electronics ',
 "HP F2105 21 '' LCD Flat Panel Monitor : Electronics ",
                         'SanDisk 2 GB Ultra II Memory Stick PRO Duo : Electronics ',
 'Garmin GPS 18 Deluxe GPS Sensor with nRoute and City Select Navigation Software ( USB Interface ) : Electronics ',
 'Monster Reference PowerCenter HTS 3500 MKII : Electronics ',
 'Creative Zen Vision W 30 GB Widescreen Multimedia Player ( Black ) : Electronics ',
  'Sandisk 512 MB Secure Digital Ultra II ( SDSDH-512-901 , Retail Package ) : Electronics ',
 'Samsung DVD-R145 DVD Recorder : Electronics ',
 'Panasonic SA-XR70S 6.1 Channel Surround Sound Home Theater Audio / Video Receiver - Silver : Electronics ',
 'Apple 4 GB iPod Nano Pink ( 2nd Generation ) : Electronics ',
 'Creative Zen Vision : M 30 GB MP3 and Video Player ( White ) : Electronics ',
 'Monster Cable MVSV2-1M High-Resolution S-Video Cable ( 1 Meter ) : Electronics ',
         'Logitech NuLOOQ Navigator ( 965162-0403 ) : Electronics ',
 "Samsung HL-R5067W 50 '' HD-Ready DLP TV : Electronics ",
 "Sony KDFE42A10 42 '' LCD Rear Projection Television : Electronics ",
 "ViewSonic Optiquest Q9b 19 '' LCD Monitor : Electronics ",
 "Samsung HL-S6187W 61 '' 1080p DLP HDTV : Electronics ",
 'Panasonic KX-TG5672B 5.8 GHz FHSS GigaRange Digital Cordless Answering System with Dual Handsets : Electronics ',
 'Panasonic DMR-ES15S DVD Recorder with DV Input : Electronics ',
 'Creative Zen V 4 GB Portable Media Player ( Black/Blue ) : Electronics ',
 'Targus PA230U Compact Universal 6 Inch Monitor Stand - Black : Electronics ',
 'Compaq iPAQ 3635 Pocket PC Bundle ( with Compact Flash Jacket ) : Electronics ',
 'Dell Axim X51v PDA 624 MHz Processor , 256MB ROM / 64MB SDRAM , 3.7 inches 480*640 VGA TFT Color LCD , BlueTooth / WiFi 802.11b/Infrared : Electronics ',
 'Cobra Nav One 4500 Mobile GPS Navigation System with Traffic : Electronics ',
 '50-pack Slim CD/DVD Jewel Cases ( 5mm ) Clear : Electronics ',
 'Kingston 256 MB Secure Digital Card ( SD/256 ) : Electronics ',
 'Xtreme TB264DKO 264-Disc CD/DVD Case : Electronics ',
 'Kingston 512 MB Secure Digital Card ( SD/512 ) : Electronics ',
 'Lexar Media 512 MB 80x Pro Series Compact Flash Card ( CF512-80-380 ) : Electronics ',
 'Kodak 8 - in - 1 Multi-card Reader , KRW8IN1SCS : Electronics ',
 'Targus PAUH212U 7 Port USB 2.0 Hub : Electronics ']

# %%
ground_truth1['sound']=['Sony SS-MF650H 3-Way Floorstanding Speakers ( Pair ) : Electronics ',
 'Sennheiser PC155 Traditional Binaural PC Headset with USB and Noise canceling : Electronics ',
 'Monster Cable QL GAS-H QuickLock Gold Angled Spade Connectors ( 2 Pair ) : Electronics ',
         'Sony MDR-V6 Monitor Series Headphones with CCAW Voice Coil : Electronics ',
 'Logitech x-230 2.1 2-Piece Dual Drive Speakers with Ported Subwoofer : Electronics ',
                        'Griffin Technology 4026-LCDT iTrip LCD FM Transmitter for iPod : Electronics ',
     'Sennheiser HD-212 Headphones ( Silver ) : Electronics ',
 'Shure E2c-n Sound Isolating Earphones ( Black ) : Electronics ',
 'Sony MDR-DS3000 Infrared Wireless Digital Surround Headphones : Electronics ',
 'Panasonic SA-XR55K 6.1-Channel A/V Home Theater Receiver , Black : Electronics ',
 'Sony HT-DDW700 Complete 5.1-Channel DVD Home Theater System : Electronics ',
 'Olympus WS-320M 1 GB Digital Voice Recorder and Music Player : Electronics ',
 'Koss R-200 Studio Quality Home Stereophone : Electronics ',
                'Sennheiser PC150 Noise Cancelling PC Headset : Electronics ',
 'Apple 4 GB iPod Nano Pink ( 2nd Generation ) : Electronics ',
 'JBL Creature II 3-Piece Powered Speaker System : Electronics ',
 'Panasonic RP-HT21 Portable Headphones : Electronics ',
 'JBL Duet Speakers , White : Electronics ',
 'Sennheiser EH-150 Evolution Hi-Fi Stereo Headphones : Electronics ',
 
 'Logitech mm50 Portable Speakers for iPod Black : Electronics ',
 'Logitech Quickcam Fusion ( 961403-0403 ) : Electronics ',
 'AKG K 26 P - Headphones ( ear-cup ) : Electronics ',
 'Sony MDR-EX51LP Fontopia In-The-Ear Headphones ( White ) : Electronics ',
 'Creative Zen Nano Plus 1 GB MP3 Player Red : Electronics ',
 'Panasonic RP-HC70 Noise Cancelling Headphones : Electronics ',
 'Ultimate Ears Super.fi 5 EB Earphones ( Black ) : Electronics ',
 'Sony MDR-EX51LP Fontopia Headphones : Electronics ',
 'Sennheiser HD 457 Traditional Open Hi-Fi Stereo Headphones ( Silver ) : Electronics ',
 'Digilife Fold-Up Compact Speakers for Apple iPod ( Travel Size ) : Electronics ',
 'Yamaha YSP-1 Digital Sound Projector : Electronics ',
 'Klipsch ProMedia 2.1 THX Certified Computer 3-Speaker System ( Black ) : Electronics ',
 'Samsung DVD-HD841 Up-Converting DVD Player : Electronics ',
 "Sony KV-36FS17 36 '' Flat-Screen TV : Electronics "]

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt 
plt.plot(final_aspect, final_precision, label = "Pricision") 
plt.plot(final_aspect, final_recall, label = "Recall")
plt.xlabel('Aspects') 
plt.ylabel('Score') 
plt.title('Evaluation Matrix!') 
plt.legend() 
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# %matplotlib notebook
plt.plot(final_aspect, final_f1score, label = "F-Score") 
plt.xlabel('Aspects') 
plt.ylabel('F-Score') 
plt.title('Evaluation Matrix!') 
plt.legend() 
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# %matplotlib notebook
plt.plot(final_aspect, final_ndcg15, label = "NDCG@15") 
plt.xlabel('Aspects') 
plt.ylabel('NDCG@15') 
plt.title('Evaluation Matrix!') 
plt.legend() 
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt 
plt.plot(final_pr_r[0],final_pr_p[0], label = "quality") 
plt.plot(final_pr_r[1],final_pr_p[1], label = "sound") 
plt.plot(final_pr_r[2],final_pr_p[2], label = "memory") 
plt.plot(final_pr_r[3],final_pr_p[3], label = "display") 
plt.plot(final_pr_r[4],final_pr_p[4], label = "screen") 

plt.ylabel('Precision') 
plt.xlabel('Recall') 

plt.title('Precision-Recall curve') 
plt.legend() 
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
cc=0
bi_grount=[]
for i in range(len(final_retrived[0])):
    bi_grount.append(1)
    
for asp in final_aspect:
    bi_predict=[]
    for pr in final_retrived[cc]:
        if(pr in ground_truth1[asp]):
            bi_predict.append(1)
        else:
            bi_predict.append(0)
    
    tn, fp, fn, tp = confusion_matrix(bi_grount,bi_predict).ravel()
    
    print("***** Aspect:", asp,"*****")
    print("tn=",tn,"  tp=",tp,)
    print("fp=",fp,"  fn=",fn)
    print("Accuracy=",((tp+tn)/(tp+tn+fp+fn))*100)
    print("")
            
        
    cc+=1
# Out:
# ***** Aspect: quality *****
# tn= 0   tp= 22
# fp= 0   fn= 8
# Accuracy= 73.33333333333333
#
# ***** Aspect: sound *****
# tn= 0   tp= 23
# fp= 0   fn= 7
# Accuracy= 76.66666666666667
#
# ***** Aspect: memory *****
# tn= 0   tp= 28
# fp= 0   fn= 2
# Accuracy= 93.33333333333333
#
# ***** Aspect: display *****
# tn= 0   tp= 28
# fp= 0   fn= 2
# Accuracy= 93.33333333333333
#
# ***** Aspect: screen *****
# tn= 0   tp= 26
# fp= 0   fn= 4
# Accuracy= 86.66666666666667

# %%
M1_acc=[96.66,86.66,93.33,90.0,90.0]
M2_acc=[73.33,76.66,93.33,93.33,86.66]

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt 
plt.plot(final_aspect, M1_acc, label = "Model:1") 
plt.plot(final_aspect, M2_acc, label = "Model:2")
plt.xlabel('Aspects') 
plt.ylabel('Accuracy') 
plt.title('Model Comparision!') 
plt.legend() 
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
